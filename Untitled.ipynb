# %% [markdown]
# # this is a notebook for test

# %%
import cv2 as cv
from matplotlib import pyplot as plt
import PreProcess
import numpy as np

# %%
img = cv.imread('test_img/test.png',cv.IMREAD_GRAYSCALE)
img = PreProcess.equalize_hist(img)
img = PreProcess.center_avg_imp(img, ksize=20)
plt.imshow(img,cmap='gray')

# %%
img = PreProcess.med_blur(img)
plt.imshow(img,cmap="gray")

# %%
import PreProcess
PreProcess.hist_segmentation(img)
# Out:
# (array([255], dtype=int64), array([0], dtype=int64))

# %%
hist = cv.calcHist([img],[0],None,[256],[0,255])
plt.plot(hist)
plt.show()

# %%
max_val = max(hist)

# %%
max_index = np.where(hist == max_val)
print(max_index)
# Out:
# (array([167], dtype=int64), array([0], dtype=int64))

# %%
mask = hist[0:max_index[0][0]]
plt.plot(mask)
plt.show()

# %%
min_index = np.where(mask == min(mask))
print(min_index)
# Out:
# (array([37], dtype=int64), array([0], dtype=int64))

# %%
ret,new_im = cv.threshold(img,37,255,cv.THRESH_BINARY)
print(ret)
plt.subplot(1,2,1)
plt.imshow(new_im,cmap='gray')
plt.subplot(1,2,2)
plt.imshow(img,cmap='gray')
plt.show()
# Out:
# 37.0

# %%
plt.imshow(cv.dilate(new_im, np.array([[1,1,1],[1,5,1],[1,1,1]])),cmap='gray')
